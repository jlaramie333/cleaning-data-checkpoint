# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df1 = pd.read_csv("Scorecard-Elements.csv")
df2 = pd.read_csv("NLSDS-Elements.csv")

print(df1.info())
print(df2.info())
# Out:
# C:\Users\Julie\AppData\Local\Temp\ipykernel_3480\63707297.py:7: DtypeWarning: Columns (735,736,737,738,739,740,742,743,744,746,748,749,750,751,752,753,755,757,761,763,764,765,766,774,776,777,778,779,787,788,789,790,791,792,800,801,802,803,804,805,813,814,816,817,818,822,826,827,829,830,831,835,839,840,841,842,843,844,847,848,852,853,854,855,856,857,860,861,874,887,891,892,893,894,895,896,898,899,900,904,905,906,907,908,909,911,912,913,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,976,990,992,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1082,1094,1095,1097,1102,1105,1106,1107,1111,1140,1141,1142,1143,1144,1145,1146,1147,1148,1149,1150,1151,1152,1153,1154,1155,1156,1157,1158,1159,1160,1161,1162,1163,1164,1165,1166,1167,1169,1170,1171,1172,1175,1176,1177) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("NSLDS-Elements.csv")
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
for col in df1.columns:
    pct_missing = np.mean(df1[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))

# There is a lot of missing data, which I could visibly see from the documents. None of the schools basic information is missing
# The columns with large numbers of missing data 
#I only want to review the first 7 columns-- these columns identify the University and 2 additional columns: 
#GRAD_DEBT_MDN_SUPP - 0% (no missing missing information)
#GRAD_DEBT_MDN10YR_SUPP - 0 (no missing information)
# Out:
# index - 0%
# UNITID - 0%
# OPEID - 0%
# OPEID6 - 0%
# INSTNM - 0%
# CITY - 0%
# STABBR - 0%
# INSTURL - 1%
# NPCURL - 7%
# HCM2 - 0%
# PREDDEG - 0%
# CONTROL - 0%
# LOCALE - 5%
# HBCU - 5%
# PBI - 5%
# ANNHI - 5%
# TRIBAL - 5%
# AANAPII - 5%
# HSI - 5%
# NANTI - 5%
# MENONLY - 5%
# WOMENONLY - 5%
# RELAFFIL - 8%
# SATVR25 - 84%
# SATVR75 - 84%
# SATMT25 - 84%
# SATMT75 - 84%
# SATWR25 - 90%
# SATWR75 - 90%
# SATVRMID - 84%
# SATMTMID - 84%
# SATWRMID - 90%
# ACTCM25 - 84%
# ACTCM75 - 84%
# ACTEN25 - 86%
# ACTEN75 - 86%
# ACTMT25 - 86%
# ACTMT75 - 86%
# ACTWR25 - 96%
# ACTWR75 - 96%
# ACTCMMID - 84%
# ACTENMID - 86%
# ACTMTMID - 86%
# ACTWRMID - 96%
# SAT_AVG - 83%
# SAT_AVG_ALL - 82%
# PCIP01 - 9%
# PCIP03 - 9%
# PCIP04 - 9%
# PCIP05 - 9%
# PCIP09 - 9%
# PCIP10 - 9%
# PCIP11 - 9%
# PCIP12 - 9%
# PCIP13 - 9%
# PCIP14 - 9%
# PCIP15 - 9%
# PCIP16 - 9%
# PCIP19 - 9%
# PCIP22 - 9%
# PCIP23 - 9%
# PCIP24 - 9%
# PCIP25 - 9%
# PCIP26 - 9%
# PCIP27 - 9%
# PCIP29 - 9%
# PCIP30 - 9%
# ...

# %%
for col in df2.columns:
    pct_missing = np.mean(df2[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
    #While more information isn't missing in this document, there are a lot of spaces that read "PrivacySuppressed"
    #All the information contained on this dataframe is in Scorecard-Elements. Therefore, I will only be using Scorecard-Elements for my project
# Out:
# index - 0%
# UNITID - 0%
# OPEID - 0%
# OPEID6 - 0%
# INSTNM - 0%
# SCH_DEG - 4%
# DEATH_YR2_RT - 5%
# COMP_ORIG_YR2_RT - 5%
# COMP_4YR_TRANS_YR2_RT - 5%
# COMP_2YR_TRANS_YR2_RT - 5%
# WDRAW_ORIG_YR2_RT - 5%
# WDRAW_4YR_TRANS_YR2_RT - 5%
# WDRAW_2YR_TRANS_YR2_RT - 5%
# ENRL_ORIG_YR2_RT - 5%
# ENRL_4YR_TRANS_YR2_RT - 5%
# ENRL_2YR_TRANS_YR2_RT - 5%
# UNKN_ORIG_YR2_RT - 5%
# UNKN_4YR_TRANS_YR2_RT - 5%
# UNKN_2YR_TRANS_YR2_RT - 5%
# LO_INC_DEATH_YR2_RT - 5%
# LO_INC_COMP_ORIG_YR2_RT - 5%
# LO_INC_COMP_4YR_TRANS_YR2_RT - 5%
# LO_INC_COMP_2YR_TRANS_YR2_RT - 5%
# LO_INC_WDRAW_ORIG_YR2_RT - 5%
# LO_INC_WDRAW_4YR_TRANS_YR2_RT - 5%
# LO_INC_WDRAW_2YR_TRANS_YR2_RT - 5%
# LO_INC_ENRL_ORIG_YR2_RT - 5%
# LO_INC_ENRL_4YR_TRANS_YR2_RT - 5%
# LO_INC_ENRL_2YR_TRANS_YR2_RT - 5%
# LO_INC_UNKN_ORIG_YR2_RT - 5%
# LO_INC_UNKN_4YR_TRANS_YR2_RT - 5%
# LO_INC_UNKN_2YR_TRANS_YR2_RT - 5%
# MD_INC_DEATH_YR2_RT - 5%
# MD_INC_COMP_ORIG_YR2_RT - 5%
# MD_INC_COMP_4YR_TRANS_YR2_RT - 5%
# ...

# %%
for col in df2.columns:
    pct_missing = np.mean(df2[col].value_counts("PrivacySuppressed"))
    print('{} - {}%'.format(col, round(pct_missing*100)))
    #This helps me understand missing information when it says "PrivacySuppressed"
# Out:
# index - 0%
# UNITID - 0%
# OPEID - 0%
# OPEID6 - 0%
# INSTNM - 0%
# SCH_DEG - 33%
# DEATH_YR2_RT - 2%
# COMP_ORIG_YR2_RT - 0%
# COMP_4YR_TRANS_YR2_RT - 0%
# COMP_2YR_TRANS_YR2_RT - 0%
# WDRAW_ORIG_YR2_RT - 0%
# WDRAW_4YR_TRANS_YR2_RT - 0%
# WDRAW_2YR_TRANS_YR2_RT - 0%
# ENRL_ORIG_YR2_RT - 0%
# ENRL_4YR_TRANS_YR2_RT - 0%
# ENRL_2YR_TRANS_YR2_RT - 0%
# UNKN_ORIG_YR2_RT - 0%
# UNKN_4YR_TRANS_YR2_RT - 1%
# UNKN_2YR_TRANS_YR2_RT - 1%
# LO_INC_DEATH_YR2_RT - 12%
# LO_INC_COMP_ORIG_YR2_RT - 0%
# LO_INC_COMP_4YR_TRANS_YR2_RT - 1%
# LO_INC_COMP_2YR_TRANS_YR2_RT - 0%
# LO_INC_WDRAW_ORIG_YR2_RT - 0%
# LO_INC_WDRAW_4YR_TRANS_YR2_RT - 0%
# LO_INC_WDRAW_2YR_TRANS_YR2_RT - 0%
# LO_INC_ENRL_ORIG_YR2_RT - 0%
# LO_INC_ENRL_4YR_TRANS_YR2_RT - 0%
# LO_INC_ENRL_2YR_TRANS_YR2_RT - 0%
# LO_INC_UNKN_ORIG_YR2_RT - 0%
# LO_INC_UNKN_4YR_TRANS_YR2_RT - 5%
# LO_INC_UNKN_2YR_TRANS_YR2_RT - 7%
# MD_INC_DEATH_YR2_RT - 100%
# MD_INC_COMP_ORIG_YR2_RT - 0%
# MD_INC_COMP_4YR_TRANS_YR2_RT - 3%
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
#find the datatype of each outlier to determine how to handle it
#The list of dataypes will be the already condensed list of rows and columns to make this section more manageable
df1.dtypes
# Out:
# index                       int64
# UNITID                      int64
# OPEID                      object
# OPEID6                      int64
# INSTNM                     object
# CITY                       object
# STABBR                     object
# UGDS                      float64
# UGDS_WHITE                float64
# UGDS_BLACK                float64
# UGDS_HISP                 float64
# UGDS_ASIAN                float64
# UGDS_AIAN                 float64
# UGDS_NHPI                 float64
# GRAD_DEBT_MDN_SUPP         object
# GRAD_DEBT_MDN10YR_SUPP     object
# dtype: object

# %%
#The first 7 columns listed above are the University's identifiers like city, state, University name, etc.
#OPEID, OPEID6, UNITID I kept as indentifiers, so if there data is missing, it isn't really relavant
#I want to look at the head now that my list is condensed
df1.head(10)
# Out:
#    index  UNITID OPEID  OPEID6                               INSTNM  \
# 0      0  100654   NaN    1002             Alabama A & M University
# 1      1  100663   NaN    1052  University of Alabama at Birmingham
# 2      2  100690   NaN   25034                   Amridge University
# 3      3  100706   NaN    1055  University of Alabama in Huntsville
# 4      4  100724   NaN    1005             Alabama State University
# 5      5  100751   NaN    1051            The University of Alabama
# 6      6  100760   NaN    1007    Central Alabama Community College
# 7      7  100812   NaN    1008              Athens State University
# 8      8  100830   NaN    8310      Auburn University at Montgomery
# 9      9  100858   NaN    1009                    Auburn University
#
#              CITY STABBR     UGDS  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# 0          Normal     AL   4206.0      0.0333      0.9353     0.0055
# 1      Birmingham     AL  11383.0      0.5922      0.2600     0.0283
# ...

# %%
#Checking to see if there is any unique values in both Grad_debt columns
columns = [['GRAD_DEBT_MDN_SUPP', 'GRAD_DEBT_MDN10YR_SUPP']]
for c in columns:
    print(df1[c].nunique())
# Out:
# GRAD_DEBT_MDN_SUPP        2060
# GRAD_DEBT_MDN10YR_SUPP    2060
# dtype: int64

# %%
#I'm looking at the Grad debt with just MO's information
df1_cleaned_MO['GRAD_DEBT_MDN_SUPP'].describe()
# Out:
# count                   200
# unique                  101
# top       PrivacySuppressed
# freq                     46
# Name: GRAD_DEBT_MDN_SUPP, dtype: object

# %%
#I'm looking at the Grad debt with just MO's information
df1_cleaned_MO['GRAD_DEBT_MDN10YR_SUPP'].describe()
# Out:
# count                   200
# unique                  101
# top       PrivacySuppressed
# freq                     46
# Name: GRAD_DEBT_MDN10YR_SUPP, dtype: object

# %%
#I'm looking at the undergraduate stats with just MO's information
df1_cleaned_MO['UGDS'].describe()
# Out:
# count      188.000000
# mean      1612.973404
# std       3646.889867
# min         11.000000
# 25%         72.000000
# 50%        252.000000
# 75%       1062.500000
# max      27276.000000
# Name: UGDS, dtype: float64

# %%
#Total number of undergraduates in the MO informational stats
df1_cleaned_MO['UGDS'].sum()
# Out:
# 303239.0

# %%
#Total number of undergraduates indentify as white in MO stats

df1_cleaned_MO['UGDS_WHITE'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.4203
# 2007       NaN
# 2008       NaN
# 2009    0.6101
# 2010    0.4642
#          ...
# 7098    0.5200
# 7102    0.4769
# 7114    0.6052
# 7238    0.2721
# 7432       NaN
# Name: UGDS_WHITE, Length: 200, dtype: float64>

# %%
#Noticed that NaN appeared when I was looking at the "Undgergraduate White" describe. Checking to see how many other null values there are
df1_cleaned_MO.isnull().sum()
# Out:
# index                      0
# UNITID                     0
# OPEID                      0
# OPEID6                     0
# INSTNM                     0
# CITY                       0
# STABBR                     0
# UGDS                      12
# UGDS_WHITE                12
# UGDS_BLACK                12
# UGDS_HISP                 12
# UGDS_ASIAN                12
# UGDS_AIAN                 12
# UGDS_NHPI                 12
# GRAD_DEBT_MDN_SUPP         0
# GRAD_DEBT_MDN10YR_SUPP     0
# dtype: int64

# %%
#Total number of undergraduates indentify as black in MO stats
df1_cleaned_MO['UGDS_BLACK'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.4034
# 2007       NaN
# 2008       NaN
# 2009    0.1893
# 2010    0.4313
#          ...
# 7098    0.3733
# 7102    0.4308
# 7114    0.2806
# 7238    0.3487
# 7432       NaN
# Name: UGDS_BLACK, Length: 200, dtype: float64>

# %%
#Total number of undergraduates indentify as hispanic in MO stats
df1_cleaned_MO['UGDS_HISP'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.0949
# 2007       NaN
# 2008       NaN
# 2009    0.0765
# 2010    0.0135
#          ...
# 7098    0.0000
# 7102    0.0396
# 7114    0.0424
# 7238    0.0315
# 7432       NaN
# Name: UGDS_HISP, Length: 200, dtype: float64>

# %%
#Total number of undergraduates indentify as Asian in MO stats
df1_cleaned_MO['UGDS_ASIAN'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.0186
# 2007       NaN
# 2008       NaN
# 2009    0.0167
# 2010    0.0155
#          ...
# 7098    0.0000
# 7102    0.0044
# 7114    0.0277
# 7238    0.0011
# 7432       NaN
# Name: UGDS_ASIAN, Length: 200, dtype: float64>

# %%
#Total number of undergraduates indentify as Amierican Indian and Alaskan Native in MO stats
df1_cleaned_MO['UGDS_AIAN'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.0051
# 2007       NaN
# 2008       NaN
# 2009    0.0083
# 2010    0.0058
#          ...
# 7098    0.0133
# 7102    0.0110
# 7114    0.0114
# 7238    0.0063
# 7432       NaN
# Name: UGDS_AIAN, Length: 200, dtype: float64>

# %%
#Total number of undergraduates indentify as North Pacific Islander in MO stats
df1_cleaned_MO['UGDS_NHPI'].describe
# Out:
# <bound method NDFrame.describe of 1361    0.0017
# 2007       NaN
# 2008       NaN
# 2009    0.0038
# 2010    0.0000
#          ...
# 7098    0.0000
# 7102    0.0066
# 7114    0.0033
# 7238    0.0042
# 7432       NaN
# Name: UGDS_NHPI, Length: 200, dtype: float64>

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#Here I am going to remove columns that I deem unnecessary for what I intend to look at. 
#Also, I am only going to look at MO university's to make this project more managable
#After I clean these columns, I will be able to go back and look at the irregular data more clearly
#I decided to only use Scorecard-Elements (df1) dataframe for my final project. This dataframe contains the information I need to answer my business question

df1_cleaned = df1.drop(columns = ['INSTURL', 'NPCURL', 'HCM2', 'PREDDEG', 'CONTROL', 'LOCALE', 'HBCU', 'PBI', 'ANNHI', 'TRIBAL', 'AANAPII', 'HSI', 'NANTI', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'SATVR25', 'SATVR75', 'SATMT25', 'SATMT75', 'SATWR25', 'SATWR75', 'SATVRMID', 'SATMTMID', 'SATWRMID', 'ACTCM25', 'ACTCM75', 'ACTEN25', 'ACTEN75', 'ACTMT25', 'ACTMT75', 'ACTWR25', 'ACTWR75', 'ACTCMMID', 'ACTENMID', 'ACTMTMID', 'ACTWRMID', 'SAT_AVG', 'SAT_AVG_ALL', 'PCIP01', 'PCIP03', 'PCIP04', 'PCIP05', 'PCIP09', 'PCIP10', 'PCIP11', 'PCIP12', 'PCIP13', 'PCIP14', 'PCIP15', 'PCIP16', 'PCIP19', 'PCIP22', 'PCIP23', 'PCIP24', 'PCIP25', 'PCIP26', 'PCIP27', 'PCIP29', 'PCIP30', 'PCIP31', 'PCIP38', 'PCIP39', 'PCIP40', 'PCIP41', 'PCIP42', 'PCIP43', 'PCIP44', 'PCIP45', 'PCIP46', 'PCIP47', 'PCIP48', 'PCIP49', 'PCIP50', 'PCIP51', 'PCIP52', 'PCIP54', 'DISTANCEONLY', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'NPT4_PUB', 'NPT4_PRIV', 'NPT41_PUB', 'NPT42_PUB', 'NPT43_PUB', 'NPT44_PUB', 'NPT45_PUB', 'NPT41_PRIV', 'NPT42_PRIV', 'NPT43_PRIV', 'NPT44_PRIV', 'NPT45_PRIV', 'PCTPELL', 'RET_FT4', 'RET_FTL4', 'RET_PT4', 'RET_PTL4', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GT_25K_P6', 'RPY_3YR_RT_SUPP', 'C150_L4_POOLED_SUPP', 'C150_4_POOLED_SUPP'])
print(df1_cleaned)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 6
#       1 #Here I am going to remove columns that I deem unnecessary for what I intend to look at.
#       2 #Also, I am only going to look at MO university's to make this project more managable
#       3 #After I clean these columns, I will be able to go back and look at the irregular data more clearly
#       4 #I decided to only use Scorecard-Elements (df1) dataframe for my final project. This dataframe contains the information I need to answer my business question
# ...

# %%
df1_cleaned_MO= df1[(df1['STABBR']== 'MO')]
print(df1_cleaned_MO)
# Out:
#       index    UNITID OPEID  OPEID6  \
# 1361   1361    155283    MO   23616
# 2007   2007    176600    MO    1632
# 2008   2008    176619    MO    2463
# 2009   2009    176628    MO    2449
# 2010   2010    176637    MO    7329
# ...     ...       ...   ...     ...
# 7098   7098    482352    MO    4057
# 7102   7102    482398    MO   40513
# 7114   7114    482538    MO   10727
# 7238   7238    484701    MO   20988
# 7432   7432  15336601    MO    1866
#
#                                           INSTNM           CITY STABBR  \
# 1361         Concorde Career College-Kansas City    Kansas City     MO
# 2007               Aquinas Institute of Theology    Saint Louis     MO
# 2008      Assemblies of God Theological Seminary    Springfield     MO
# 2009                            Avila University    Kansas City     MO
# 2010          ITT Technical Institute-Earth City     Earth City     MO
# ...                                          ...            ...    ...
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
df1_cleaned_MO.head(50)
# Out:
#       index  UNITID OPEID  OPEID6  \
# 1361   1361  155283    MO   23616
# 2007   2007  176600    MO    1632
# 2008   2008  176619    MO    2463
# 2009   2009  176628    MO    2449
# 2010   2010  176637    MO    7329
# 2011   2011  176664    MO   13208
# 2012   2012  176716    MO   22775
# 2013   2013  176770    MO   20682
# 2014   2014  176789    MO    2450
# 2015   2015  176798    MO    5532
# 2016   2016  176910    MO   22664
# 2017   2017  176947    MO    2453
# 2018   2018  176965    MO    2454
# 2019   2019  176983    MO    5531
# 2020   2020  176992    MO   21659
# 2022   2022  177056    MO   22892
# 2023   2023  177065    MO    2456
# 2024   2024  177083    MO    2467
# 2025   2025  177092    MO    2457
# 2026   2026  177117    MO    2458
# 2027   2027  177126    MO    4707
# 2028   2028  177135    MO    2459
# 2029   2029  177144    MO    2460
# 2030   2030  177214    MO    2461
# 2031   2031  177250    MO    8862
# 2032   2032  177278    MO    2462
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset? Yes
# 2. Did the process of cleaning your data give you new insights into your dataset? Yes, it gave me A LOT more insight. I ended up even deciding the 2nd dataframe wasn't giving any new information, so decided to only use the 1 for the final project. I narrowed it down to only 16 columns and 200 rows, since I will only be reviewing MO univeristies/colleges
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations? I'd like to make note of that NaN is in the chart 12 times for each race. And the Grad_debt has "PrivacySuppressed" instead of a value if the information isn't available.
